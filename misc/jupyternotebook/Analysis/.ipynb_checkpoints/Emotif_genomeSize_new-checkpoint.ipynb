# %%
#!~/.conda/envs/lra/bin/python3
import os
import sys
import re
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
from collections import defaultdict 
import numpy as np
# import UnionFind
import edlib
import math

path = "/project/mchaisso_100/cmb-16/jingwenr/trfCall/revision"

# %%
def update_data_dict(delta, genome_size, omotif_size, emotif_size, vntr_size, avg_omtifs_size, avg_emotifs_size, ratio):
    data_dict['delta'].append(delta)
    data_dict['genome_size'].append(genome_size)
    data_dict['omotif_size'].append(omotif_size)
    data_dict['emotif_size'].append(emotif_size)
    data_dict['vntr_size'].append(vntr_size)
    data_dict['avg_omtifs_size'].append(avg_omtifs_size)
    data_dict['avg_emotifs_size'].append(avg_emotifs_size)
    data_dict['ratio'].append(ratio)

# %%
def collectInfo(genomeSize):
    vntr2omotif_size = defaultdict(int)
    num_omotif = 0 
    num_vntrs = 0
    
    # read original motif file 
    file = f"{path}/vntr_motif_database/out-{genomeSize}/original_adjusted/vntr_motifs.bed"
    with open(file, 'r') as f:
        lines = f.readlines()
        for line in lines:
            line = line.rstrip("\n")
            fields = line.split('\t')
            chrom, start, end = fields[:3]
            vntr = f"{chrom}_{start}-{end}"
            num_omotif += len(fields[3].split(','))
            vntr2omotif_size[vntr] = len(fields[3].split(','))
            num_vntrs += 1
    
    update_data_dict("original", genomeSize, num_omotif, num_omotif, \
                     num_vntrs, num_omotif / num_vntrs, \
                     num_omotif / num_vntrs, 1.0)
    
    for delta in ["q-0.1", "q-0.2", "q-0.3"]:
        
        num_emotif = 0
        ratio_sum = 0
        
        # read efficient motif file 
        file = f"{path}/vntr_motif_database/out-{genomeSize}/{delta}_adjusted/vntr_motifs.bed"
        with open(file, 'r') as f:
            lines = f.readlines()
            for line in lines:
                line = line.rstrip("\n")
                fields = line.split('\t')
                chrom, start, end = fields[:3]
                vntr = f"{chrom}_{start}-{end}"
                num_emotif += len(fields[3].split(','))
                ratio_sum += len(fields[3].split(',')) / vntr2omotif_size[vntr]
                
        update_data_dict(delta, genomeSize, num_omotif, num_emotif, \
                         num_vntrs, num_omotif / num_vntrs, \
                         num_emotif / num_vntrs, ratio_sum / num_vntrs)

# %%
data_dict = {"delta" : [], \
             "genome_size": [], \
             "omotif_size" : [], \
             "emotif_size" : [], \
             "vntr_size" : [], \
             "avg_omtifs_size" : [], \
             "avg_emotifs_size" : [], \
             "ratio" : [] \
            }

for genomeSize in [1, 30, 60, 64, 90, 120, 148]:
    collectInfo(genomeSize)

# %%
df = pd.DataFrame(data_dict) 
df
# Out:
#        delta  genome_size  omotif_size  emotif_size  vntr_size  \
# 0   original            1      1474384      1474384     371502
# 1      q-0.1            1      1474384      1314140     371502
# 2      q-0.2            1      1474384      1101424     371502
# 3      q-0.3            1      1474384       929576     371502
# 4   original           30      2824749      2824749     389795
# 5      q-0.1           30      2824749      1739104     389795
# 6      q-0.2           30      2824749      1279715     389795
# 7      q-0.3           30      2824749      1010043     389795
# 8   original           60      3164511      3164511     389675
# 9      q-0.1           60      3164511      1741975     389675
# 10     q-0.2           60      3164511      1287367     389675
# 11     q-0.3           60      3164511      1014717     389675
# 12  original           64      3200459      3200459     389558
# 13     q-0.1           64      3200459      1741486     389558
# 14     q-0.2           64      3200459      1288876     389558
# 15     q-0.3           64      3200459      1022130     389558
# 16  original           90      3261805      3261805     389931
# 17     q-0.1           90      3261805      1714060     389931
# 18     q-0.2           90      3261805      1274922     389931
# 19     q-0.3           90      3261805      1012815     389931
# 20  original          120      3395637      3395637     390035
# 21     q-0.1          120      3395637      1706411     390035
# 22     q-0.2          120      3395637      1271600     390035
# 23     q-0.3          120      3395637      1003269     390035
# 24  original          148      3498714      3498714     390115
# 25     q-0.1          148      3498714      1703653     390115
# 26     q-0.2          148      3498714      1272171     390115
# 27     q-0.3          148      3498714      1013359     390115
#
#     avg_omtifs_size  avg_emotifs_size     ratio
# 0          3.968711          3.968711  1.000000
# 1          3.968711          3.537370  0.968866
# 2          3.968711          2.964786  0.890179
# 3          3.968711          2.502210  0.813818
# 4          7.246755          7.246755  1.000000
# 5          7.246755          4.461586  0.849626
# 6          7.246755          3.283046  0.743510
# 7          7.246755          2.591216  0.677795
# 8          8.120898          8.120898  1.000000
# 9          8.120898          4.470328  0.815867
# 10         8.120898          3.303694  0.715014
# 11         8.120898          2.604008  0.652258
# 12         8.215616          8.215616  1.000000
# 13         8.215616          4.470415  0.812499
# 14         8.215616          3.308560  0.712168
# 15         8.215616          2.623820  0.649729
# 16         8.365083          8.365083  1.000000
# 17         8.365083          4.395803  0.803408
# 18         8.365083          3.269609  0.706027
# 19         8.365083          2.597421  0.644828
# 20         8.705980          8.705980  1.000000
# 21         8.705980          4.375020  0.790514
# 22         8.705980          3.260220  0.695287
# 23         8.705980          2.572254  0.635191
# 24         8.968417          8.968417  1.000000
# 25         8.968417          4.367053  0.780825
# 26         8.968417          3.261015  0.687072
# 27         8.968417          2.597590  0.627858

# %%
plt.figure(figsize=(15, 12))

ax = sns.lineplot(data=df, x="genome_size", y="emotif_size", \
                  hue="delta", style="delta", palette="deep", \
                  markers=True, dashes=False, lw=3, markersize=12)
# plt.ylim([100000, 3700000])
plt.xlabel('Number of assemblies added', fontsize=32)
plt.ylabel('Number of efficient motifs', fontsize=32)
ax.set_xticks([1, 30, 60, 64, 90, 120, 148])
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.yaxis.offsetText.set_fontsize(20)
handles, labels = ax.get_legend_handles_labels()
# update labels
for i in range(len(labels)):
    if labels[i] == 'original':
        labels[i] = 'q=0(original)'
    else:
        labels[i] = 'q=' + labels[i][2:]
legend = ax.legend(handles=handles, labels=labels, title="compression strength",fontsize=20, fancybox=True)
plt.setp(legend.get_title(),fontsize=20)
# plt.savefig(f"{path}/plot/emotifs_genomesize_overall.png", dpi=300,  bbox_inches = 'tight')


plt.show()  
plt.close()

# %% [markdown]
# # num of vntrs

# %%
df.loc[df['delta'] == 'q-0.1']
# Out:
#     delta  genome_size  omotif_size  emotif_size  vntr_size  avg_omtifs_size  \
# 1   q-0.1            1      1474384      1314140     371502         3.968711
# 5   q-0.1           30      2824749      1739104     389795         7.246755
# 9   q-0.1           60      3164511      1741975     389675         8.120898
# 13  q-0.1           64      3200459      1741486     389558         8.215616
# 17  q-0.1           90      3261805      1714060     389931         8.365083
# 21  q-0.1          120      3395637      1706411     390035         8.705980
# 25  q-0.1          148      3498714      1703653     390115         8.968417
#
#     avg_emotifs_size     ratio
# 1           3.537370  0.968866
# 5           4.461586  0.849626
# 9           4.470328  0.815867
# 13          4.470415  0.812499
# 17          4.395803  0.803408
# 21          4.375020  0.790514
# 25          4.367053  0.780825

# %%
df.loc[df['delta'] == 'original']
# Out:
#        delta  genome_size  omotif_size  emotif_size  vntr_size  \
# 0   original            1      1474384      1474384     371502
# 4   original           30      2824749      2824749     389795
# 8   original           60      3164511      3164511     389675
# 12  original           64      3200459      3200459     389558
# 16  original           90      3261805      3261805     389931
# 20  original          120      3395637      3395637     390035
# 24  original          148      3498714      3498714     390115
#
#     avg_omtifs_size  avg_emotifs_size  ratio
# 0          3.968711          3.968711    1.0
# 4          7.246755          7.246755    1.0
# 8          8.120898          8.120898    1.0
# 12         8.215616          8.215616    1.0
# 16         8.365083          8.365083    1.0
# 20         8.705980          8.705980    1.0
# 24         8.968417          8.968417    1.0

# %% [markdown]
# # % original motifs are added after 64 genomes

# %%
g = 64
size = list(df.loc[(df['genome_size'] == 64) & (df['delta'] == 'q-0.1')]['omotif_size']) 
size_full = list(df.loc[(df['genome_size'] == 148) & (df['delta'] == 'q-0.1')]['omotif_size'])

print(size[0], size_full[0])
print("% original motifs are added after 64 genomes")
print([size[i] / size_full[i] for i in range(len(size_full))])
# Out:
# 3200459 3498714
# % original motifs are added after 64 genomes
# [0.9147529635174524]

# %% [markdown]
# # % efficient motifs are added after 64 genomes

# %%
g = 64
size = list(df.loc[(df['genome_size'] == 64) & (df['delta'] == 'q-0.1')]['emotif_size']) 
size_full = list(df.loc[(df['genome_size'] == 148) & (df['delta'] == 'q-0.1')]['emotif_size'])

print(size[0], size_full[0])
print("% efficient motifs are added after 64 genomes")
print([size[i] / size_full[i] for i in range(len(size_full))])
# Out:
# 1741486 1703653
# % efficient motifs are added after 64 genomes
# [1.0222069869861996]

# %% [markdown]
# # Average original/efficient motif set size

# %%
print("original average omoitf size", df.loc[(df['delta'] == "original") & (df['genome_size'] == 148)]['avg_omtifs_size'])
print()


print("q-0.1 average omoitf size", df.loc[(df['delta'] == "q-0.1") & (df['genome_size'] == 148)]['avg_emotifs_size'])
print()


print("q-0.2 average omoitf size", df.loc[(df['delta'] == "q-0.2") & (df['genome_size'] == 148)]['avg_emotifs_size'])
print()


print("q-0.3 average omoitf size", df.loc[(df['delta'] == "q-0.3") & (df['genome_size'] == 148)]['avg_emotifs_size'])
print()
# Out:
# original average omoitf size 24    8.968417
# Name: avg_omtifs_size, dtype: float64
#
# q-0.1 average omoitf size 25    4.367053
# Name: avg_emotifs_size, dtype: float64
#
# q-0.2 average omoitf size 26    3.261015
# Name: avg_emotifs_size, dtype: float64
#
# q-0.3 average omoitf size 27    2.59759
# Name: avg_emotifs_size, dtype: float64

# %% [markdown]
# # Median  motif set ratio

# %%
print("original average ratio", df.loc[(df['delta'] == "original") & (df['genome_size'] == 148)]['ratio'].median())
print("q-0.1 average ratio", df.loc[(df['delta'] == "q-0.1") & (df['genome_size'] == 148)]['ratio'].median())
print("q-0.2 quantile average ratio", df.loc[(df['delta'] == "q-0.2") & (df['genome_size'] == 148)]['ratio'].median())
print("q-0.3 quantile average ratio", df.loc[(df['delta'] == "q-0.3") & (df['genome_size'] == 148)]['ratio'].median())
# Out:
# original average ratio 1.0
# q-0.1 average ratio 0.7808249061290665
# q-0.2 quantile average ratio 0.6870724745364811
# q-0.3 quantile average ratio 0.6278575243262872
